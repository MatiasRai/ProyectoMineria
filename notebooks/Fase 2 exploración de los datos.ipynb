# %%
# %load_ext kedro.ipython
# Out:
# [04/12/25 22:38:19] INFO     Using                                                                  ]8;id=65032;file://C:\Users\matia\AppData\Local\Programs\Python\Python310\lib\site-packages\kedro\framework\project\__init__.py\__init__.py]8;;\:]8;id=40342;file://C:\Users\matia\AppData\Local\Programs\Python\Python310\lib\site-packages\kedro\framework\project\__init__.py#249\249]8;;\
#                              'C:\Users\matia\AppData\Local\Programs\Python\Python310\lib\site-packa
#                              ges\kedro\framework\project\rich_logging.yml' as logging
#                              configuration.
#                     INFO     Registered line magic '%reload_kedro'                                   ]8;id=38043;file://C:\Users\matia\AppData\Local\Programs\Python\Python310\lib\site-packages\kedro\ipython\__init__.py\__init__.py]8;;\:]8;id=630202;file://C:\Users\matia\AppData\Local\Programs\Python\Python310\lib\site-packages\kedro\ipython\__init__.py#58\58]8;;\
#                     INFO     Registered line magic '%load_node'                                      ]8;id=62419;file://C:\Users\matia\AppData\Local\Programs\Python\Python310\lib\site-packages\kedro\ipython\__init__.py\__init__.py]8;;\:]8;id=157640;file://C:\Users\matia\AppData\Local\Programs\Python\Python310\lib\site-packages\kedro\ipython\__init__.py#60\60]8;;\
#                     INFO     Resolved project path as:                                              ]8;id=387419;file://C:\Users\matia\AppData\Local\Programs\Python\Python310\lib\site-packages\kedro\ipython\__init__.py\__init__.py]8;;\:]8;id=253135;file://C:\Users\matia\AppData\Local\Programs\Python\Python310\lib\site-packages\kedro\ipython\__init__.py#175\175]8;;\
#                              C:\Users\matia\OneDrive\Escritorio\ProyectoStarcraft\ProyectoMineria.
#                              To set a different path, run '%reload_kedro <project_root>'
# [04/12/25 22:38:33] INFO     Kedro is sending anonymous usage data with the sole purpose of improving ]8;id=636741;file://C:\Users\matia\AppData\Local\Programs\Python\Python310\lib\site-packages\kedro_telemetry\plugin.py\plugin.py]8;;\:]8;id=915464;file://C:\Users\matia\AppData\Local\Programs\Python\Python310\lib\site-packages\kedro_telemetry\plugin.py#233\233]8;;\
#                              the product. No personal data or IP addresses are stored on our side. If
#                              you want to opt out, set the `KEDRO_DISABLE_TELEMETRY` or `DO_NOT_TRACK`
#                              environment variables, or create a `.telemetry` file in the current
#                              working directory with the contents `consent: false`. Read more at
#                              https://docs.kedro.org/en/stable/configuration/telemetry.html
# [04/12/25 22:38:34] INFO     Kedro project psicologia                                               ]8;id=523705;file://C:\Users\matia\AppData\Local\Programs\Python\Python310\lib\site-packages\kedro\ipython\__init__.py\__init__.py]8;;\:]8;id=136294;file://C:\Users\matia\AppData\Local\Programs\Python\Python310\lib\site-packages\kedro\ipython\__init__.py#141\141]8;;\
#                     INFO     Defined global variable 'context', 'session', 'catalog' and            ]8;id=837732;file://C:\Users\matia\AppData\Local\Programs\Python\Python310\lib\site-packages\kedro\ipython\__init__.py\__init__.py]8;;\:]8;id=681915;file://C:\Users\matia\AppData\Local\Programs\Python\Python310\lib\site-packages\kedro\ipython\__init__.py#142\142]8;;\
#                              'pipelines'

# %%
catalog
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# {'starcraft_duoc': "kedro_datasets.pandas.csv_dataset.CSVDataset(filepath=PurePosixPath('C:/Users/matia/OneDrive/Escritorio/ProyectoStarcraft/ProyectoMineria/data/01_raw/starcraft_duoc.csv'), "
#                    "protocol='file', load_args={'delimiter': ';', "
#                    "'on_bad_lines': 'skip'}, save_args={'index': False})",
#  'nulos_data': "kedro_datasets.pandas.csv_dataset.CSVDataset(filepath=PurePosixPath('C:/Users/matia/OneDrive/Escritorio/ProyectoStarcraft/ProyectoMineria/data/02_intermediate/nulos_data.csv'), "
#                "protocol='file', load_args={}, save_args={'index': False})",
#  'imputed_data': "kedro_datasets.pandas.csv_dataset.CSVDataset(filepath=PurePosixPath('C:/Users/matia/OneDrive/Escritorio/ProyectoStarcraft/ProyectoMineria/data/02_intermediate/imputed_data.csv'), "
#                  "protocol='file', load_args={}, save_args={'index': False})",
#  'mapped_data': "kedro_datasets.pandas.csv_dataset.CSVDataset(filepath=PurePosixPath('C:/Users/matia/OneDrive/Escritorio/ProyectoStarcraft/ProyectoMineria/data/02_intermediate/mapped_data.csv'), "
#                 "protocol='file', load_args={}, save_args={'index': False})",
#  'X_test_balanced': "kedro_datasets.pandas.csv_dataset.CSVDataset(filepath=PurePosixPath('C:/Users/matia/OneDrive/Escritorio/ProyectoStarcraft/ProyectoMineria/data/05_model_input/X_test_balanced.csv'), "
#                     "protocol='file', load_args={}, save_args={'index': "
#                     'False})',
#  'y_test_balanced': "kedro_datasets.pandas.csv_dataset.CSVDataset(filepath=PurePosixPath('C:/Users/matia/OneDrive/Escritorio/ProyectoStarcraft/ProyectoMineria/data/05_model_input/y_test_balanced.csv'), "
#                     "protocol='file', load_args={}, save_args={'index': "
#                     'False})',
#  'xgb_model': "kedro_datasets.pickle.pickle_dataset.PickleDataset(filepath=PurePosixPath('C:/Users/matia/OneDrive/Escritorio/ProyectoStarcraft/ProyectoMineria/data/06_models/xgb_model.pkl'), "
#               "backend='pickle', protocol='file', load_args={}, save_args={})",
#  'knn_model': "kedro_datasets.pickle.pickle_dataset.PickleDataset(filepath=PurePosixPath('C:/Users/matia/OneDrive/Escritorio/ProyectoStarcraft/ProyectoMineria/data/06_models/knn_model.pkl'), "
#               "backend='pickle', protocol='file', load_args={}, save_args={})",
#  'rf_model': "kedro_datasets.pickle.pickle_dataset.PickleDataset(filepath=PurePosixPath('C:/Users/matia/OneDrive/Escritorio/ProyectoStarcraft/ProyectoMineria/data/06_models/rf_model.pkl'), "
#              "backend='pickle', protocol='file', load_args={}, save_args={})",
#  'logistic_regression_model': "kedro_datasets.pickle.pickle_dataset.PickleDataset(filepath=PurePosixPath('C:/Users/matia/OneDrive/Escritorio/ProyectoStarcraft/ProyectoMineria/data/06_models/logistic_regression_model.pkl'), "
#                               "backend='pickle', protocol='file', "
#                               'load_args={}, save_args={})',
#  'parameters': "kedro.io.memory_dataset.MemoryDataset(data='<dict>')"}

# %% [markdown]
# ***Importamos las librerias para trabajar en esta fase.***

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# %%
###%reload_kedro

# %% [markdown]
# ***Cargaremos el dataset.***

# %%
df=catalog.load("starcraft_duoc")
df.head()
# Out:
# [04/12/25 22:38:55] INFO     Loading data from starcraft_duoc (CSVDataset)...                   ]8;id=645918;file://C:\Users\matia\AppData\Local\Programs\Python\Python310\lib\site-packages\kedro\io\data_catalog.py\data_catalog.py]8;;\:]8;id=75991;file://C:\Users\matia\AppData\Local\Programs\Python\Python310\lib\site-packages\kedro\io\data_catalog.py#539\539]8;;\
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#    GameID  LeagueIndex   Age  HoursPerWeek  TotalHours        APM  \
# 0      52            5  27.0          10.0      3000.0    143.718
# 1      55            5  23.0          10.0      5000.0  1.292.322
# 2      56            4  30.0          10.0       200.0    699.612
# 3      57            3  19.0          20.0       400.0  1.076.016
# 4      58            3  32.0          10.0       500.0  1.228.908
#
#   SelectByHotkeys AssignToHotkeys MinimapAttacks MinimapRightClicks  \
# 0     0.003515159     0.000219697    0.000109849        0.000392317
# 1     0.003303812     0.000259462    0.000294057        0.000432436
# 2     0.001101091      0.00033557    0.000293624        0.000461409
# 3     0.001033542     0.000213101       5.33e-05        0.000543409
# 4     0.001136014     0.000327326              0        0.001328558
#
#    NumberOfPACs GapBetweenPACs ActionLatency  ActionsInPAC  TotalMapExplored  \
# 0      0.004849        326.677       408.673        47.508          0.000220
# 1      0.004307        329.194       423.454        48.434          0.000381
# 2      0.002926        446.475       753.548         4.043          0.000231
# 3      0.003783        292.203       537.352        49.155          0.000202
# 4      0.002368        226.885       620.813         9.374          0.000289
#
#   WorkersMade UniqueUnitsMade ComplexUnitsMade ComplexAbilityUsed  \
# 0   0.0013966        4.71e-05                0                  0
# 1   0.0011935        8.65e-05                0         0.00020757
# 2  0.00074455        6.29e-05                0         0.00018876
# 3   0.0004262        7.46e-05                0         0.00038358
# 4   0.0011745         7.7e-05                0           1.93e-05
#
#    MaxTimeStamp
# 0        127448
# 1         57812
# 2         95360
# 3         93852
# 4         51936

# %% [markdown]
# ***Verificamos el número de columnas y filas del dataset.***

# %%
num_rows, num_columns = df.shape
# Mostrar el resultado
print(f"El dataset tiene {num_columns} columnas y {num_rows} filas.")
# Out:
# El dataset tiene 20 columnas y 3395 filas.

# %%
df.describe()
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#              GameID  LeagueIndex          Age  HoursPerWeek      TotalHours  \
# count   3395.000000  3395.000000  3340.000000   3339.000000     3338.000000
# mean    4805.012371     4.184094    21.647904     15.910752      960.421809
# std     2719.944851     1.517327     4.206341     11.962912    17318.133922
# min       52.000000     1.000000    16.000000      0.000000        3.000000
# 25%     2464.500000     3.000000    19.000000      8.000000      300.000000
# 50%     4874.000000     4.000000    21.000000     12.000000      500.000000
# 75%     7108.500000     5.000000    24.000000     20.000000      800.000000
# max    10095.000000     8.000000    44.000000    168.000000  1000000.000000
#
#        NumberOfPACs  ActionsInPAC  TotalMapExplored   MaxTimeStamp
# count   3395.000000   3395.000000       3395.000000    3395.000000
# mean       0.003463     47.216492          0.000283   83598.229161
# std        0.000992     20.604812          0.000087   33497.667966
# min        0.000679      2.454000          0.000091   25224.000000
# 25%        0.002754     38.993500          0.000224   60090.000000
# 50%        0.003395     48.797000          0.000270   81012.000000
# 75%        0.004027     58.717500          0.000325  102074.000000
# max        0.007971    185.581000          0.000832  388032.000000

# %% [markdown]
# ***Verificamos el tipo de dato de cada columna.***

# %%
df.dtypes #tipo de datos de todas las columnas
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# GameID                  int64
# LeagueIndex             int64
# Age                   float64
# HoursPerWeek          float64
# TotalHours            float64
# APM                    object
# SelectByHotkeys        object
# AssignToHotkeys        object
# MinimapAttacks         object
# MinimapRightClicks     object
# NumberOfPACs          float64
# GapBetweenPACs         object
# ActionLatency          object
# ActionsInPAC          float64
# TotalMapExplored      float64
# WorkersMade            object
# UniqueUnitsMade        object
# ComplexUnitsMade       object
# ComplexAbilityUsed     object
# MaxTimeStamp            int64
# dtype: object

# %% [markdown]
# **Luego realizamos un analisis descriptivo**

# %%
# Análisis descriptivo de las variables
print(df.describe())
# Out:
#              GameID  LeagueIndex          Age  HoursPerWeek      TotalHours  \
# count   3395.000000  3395.000000  3340.000000   3339.000000     3338.000000
# mean    4805.012371     4.184094    21.647904     15.910752      960.421809
# std     2719.944851     1.517327     4.206341     11.962912    17318.133922
# min       52.000000     1.000000    16.000000      0.000000        3.000000
# 25%     2464.500000     3.000000    19.000000      8.000000      300.000000
# 50%     4874.000000     4.000000    21.000000     12.000000      500.000000
# 75%     7108.500000     5.000000    24.000000     20.000000      800.000000
# max    10095.000000     8.000000    44.000000    168.000000  1000000.000000
#
#        NumberOfPACs  ActionsInPAC  TotalMapExplored   MaxTimeStamp
# count   3395.000000   3395.000000       3395.000000    3395.000000
# mean       0.003463     47.216492          0.000283   83598.229161
# std        0.000992     20.604812          0.000087   33497.667966
# min        0.000679      2.454000          0.000091   25224.000000
# 25%        0.002754     38.993500          0.000224   60090.000000
# 50%        0.003395     48.797000          0.000270   81012.000000
# 75%        0.004027     58.717500          0.000325  102074.000000
# max        0.007971    185.581000          0.000832  388032.000000

# %% [markdown]
# **Aqui verificamos si existen valores nulos en nuestro dataset**

# %%
# Verificar si hay valores nulos en el dataset
print(df.isnull().sum())
# Out:
# GameID                 0
# LeagueIndex            0
# Age                   55
# HoursPerWeek          56
# TotalHours            57
# APM                    0
# SelectByHotkeys        0
# AssignToHotkeys        0
# MinimapAttacks         0
# MinimapRightClicks     0
# NumberOfPACs           0
# GapBetweenPACs         0
# ActionLatency          0
# ActionsInPAC           0
# TotalMapExplored       0
# WorkersMade            0
# UniqueUnitsMade        0
# ComplexUnitsMade       0
# ComplexAbilityUsed     0
# MaxTimeStamp           0
# dtype: int64

# %% [markdown]
# **Creamos un boxplot para visualizar los outliers de las variables numéricas**

# %%
plt.figure(figsize=(10,6))
sns.boxplot(data=df[['APM', 'HoursPerWeek', 'TotalHours']])
plt.title("Boxplot de APM, HoursPerWeek, y TotalHours")
plt.show()
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <Figure size 1000x600 with 1 Axes>

# %% [markdown]
# **Usaremos IQR para detecteras outliers, esto basicamente es para hacerlo de manera más estadistica.**

# %%
# Asegúrate de que las columnas sean numéricas
df['APM'] = pd.to_numeric(df['APM'], errors='coerce')
df['HoursPerWeek'] = pd.to_numeric(df['HoursPerWeek'], errors='coerce')
df['TotalHours'] = pd.to_numeric(df['TotalHours'], errors='coerce')

# %%
# Calcular el IQR (Rango Intercuartílico)
Q1 = df[['APM', 'HoursPerWeek', 'TotalHours']].quantile(0.25)
Q3 = df[['APM', 'HoursPerWeek', 'TotalHours']].quantile(0.75)
IQR = Q3 - Q1

# Definir los límites inferior y superior para detectar outliers
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

# Ver cuántos valores están fuera de los límites
outliers = (df[['APM', 'HoursPerWeek', 'TotalHours']] < lower_bound) | (df[['APM', 'HoursPerWeek', 'TotalHours']] > upper_bound)
print(outliers.sum())
# Out:
# APM               0
# HoursPerWeek    171
# TotalHours      169
# dtype: int64
