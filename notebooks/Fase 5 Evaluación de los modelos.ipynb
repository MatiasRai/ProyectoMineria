# %% [markdown]
# **Objetivos de la Fase de Evaluación :**
# Evaluar los modelos entrenadorespuntuación precisión , recuperación ) .​: Haremos una comparación entre los modelos que entrenamos, observando las métricas de rendimiento (exactitud, puntuación f1, precisión, recuperación).
#
# **Conclusión :** Basándonos en las métricas obtenidas, podemos concluir cuál es el modelo más adecuado para la tarea de clasificación de LeagueIndexen este conjunto de datos.
#
# **Justificación técnica :** Explicaremos las decisiones que tomamos durante el proceso, por qué elegimos ciertas técnicas y cuál es el valor de cada uno de los modelos probados.
#
# **📊 Evaluación de los Modelos**
# Comenzaremos por revisar los resultados de los modelos que hemos entrenado:
#
# Bosque aleatorioaleatorio:
#
# Exactitud :0.37
#
# Puntuación macro F1 :0.39
#
# Puntuación F1 ponderada​:0.37
#
# Regresión logísticalogística:
#
# Exactitud :0.33
#
# Puntuación macro F1 :0.23
#
# Puntuación F1 ponderada :​:0.32
#
# K-Vecinos más cercanos (KNN) :
#
# Exactitud :0.27
#
# Puntuación macro F1 :0.25
#
# Puntuación F1 ponderada :0.27
#
# XGBoost (con SMOTE):
#
# Exactitud :0.37
#
# Puntuación macro F1 :0.39
#
# Puntuación F1 ponderada :0.37
#
# Aumento de gradiente :
#
# Exactitud :0.26
#
# Puntuación macro F1 :0.17
#
# Puntuación F1 ponderada :0.27
#
# ![image.png](attachment:f15c6ccd-183e-4d55-b41d-ef04fbfbf539.png)
#
# **Observaciones :**
# Mejor rendimiento en XGBoost y Random Forest :
#
# Ambos modelos presentan un rendimiento relativamente equilibrado ((precisión de 0,37) y mejor capacidad de generalización (macro f1-score de 0,39).
#
# XGBoost y Random Forest tienentienen un rendimiento notablemente superior en comparación con Regresión Logísticalogística, KNN , y Aumento de gradiente .
#
# Clase 7 sigue siendo un desafío :
#
# Ninguno de los modelos logra predecir correctamente la Clase 7 ((que tiene solo 4 ejemplos).
#
# Esto muestra un desequilibrio de clases severo . Aunque SMOTE fue aplicado, la clase 7 sigue siendo un reto por la escasez de datos.
#
# Modelo KNN y Gradient Boosting tienen peor rendimiento :
#
# Ambos modelos tienen métricas más bajas en comparación. concon Random Forest y XGBoost, especialmente en el f1-score .
#
# Regresión Logística no logró mejorar el rendimiento:
#
# A pesar de ser un modelo simple, regresión logística.logística mostró una precisiónmostró una precisión relativamente baja, lo que sugiere que no es el mejor modelo para este conjunto de datos.
#
# **Conclusiones y Recomendaciones :**
# XGBoost es el mejor modelo en términos de rendimiento general . Con una precisión de 0,37 y un fes el mejor modelo en términos de rendimiento general. Con una precisión de 0,37 y una puntuación f1 de 0,39 , es el modelo más robusto en este caso, a pesar de las dificultades con la clase 7.
#
# Bosque aleatorio también es una buena opción , con resultados similares a XGBoostclara , es menos complejo y también presenta un rendimiento .También es una buena opción, con resultados similares a XGBoost. Aunque no ofrece una clara ventaja, es menos complejo y también presenta un rendimiento satisfactorio.
#
# **Mejoras :**
#
# Balanceo de clases : Aunque SMOTE ayudó , se recomienda explorar técnicasayudado, se recomienda explorar técnicas avanzadas de balanceo como SMOTEENN o undersampling.o submuestreo para mejorar la predicción de clases minoritarias.
#
# Optimización de hiperparámetros : Se sugiere hacer una búsqueda de hiperparámetros ( como con o(como con GridSearchCVo RandomizedSearchCV) para mejorar el rendimiento de XGBoost.
#
# Más datos : Incrementar el número de ejemplos de clases como la clase 7 podría mejorar significativamente los resultados, ya que el modelo no puede aprender correctamente con tan pocos ejemplos.
#
# Recomendación final : Para este problema específico, XGBoost con SMOTE parece ser la opción más adecuada para obtener los mejores resultados en predicción, especialmente en ligas de jugadores más comunes. Sin embargo, se debe trabajar en el equilibrio de clases y explorar más datos.
