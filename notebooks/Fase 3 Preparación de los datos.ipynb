# %%
# %load_ext kedro.ipython
# Out:
# [04/13/25 01:44:45] INFO     Using                                                                  ]8;id=808243;file://C:\Users\matia\AppData\Local\Programs\Python\Python313\Lib\site-packages\kedro\framework\project\__init__.py\__init__.py]8;;\:]8;id=190577;file://C:\Users\matia\AppData\Local\Programs\Python\Python313\Lib\site-packages\kedro\framework\project\__init__.py#270\270]8;;\
#                              'C:\Users\matia\AppData\Local\Programs\Python\Python313\Lib\site-packa
#                              ges\kedro\framework\project\rich_logging.yml' as logging
#                              configuration.
#                     INFO     Registered line magic '%reload_kedro'                                   ]8;id=745701;file://C:\Users\matia\AppData\Local\Programs\Python\Python313\Lib\site-packages\kedro\ipython\__init__.py\__init__.py]8;;\:]8;id=719838;file://C:\Users\matia\AppData\Local\Programs\Python\Python313\Lib\site-packages\kedro\ipython\__init__.py#63\63]8;;\
#                     INFO     Registered line magic '%load_node'                                      ]8;id=608206;file://C:\Users\matia\AppData\Local\Programs\Python\Python313\Lib\site-packages\kedro\ipython\__init__.py\__init__.py]8;;\:]8;id=69320;file://C:\Users\matia\AppData\Local\Programs\Python\Python313\Lib\site-packages\kedro\ipython\__init__.py#65\65]8;;\
#                     INFO     Resolved project path as:                                              ]8;id=361755;file://C:\Users\matia\AppData\Local\Programs\Python\Python313\Lib\site-packages\kedro\ipython\__init__.py\__init__.py]8;;\:]8;id=336469;file://C:\Users\matia\AppData\Local\Programs\Python\Python313\Lib\site-packages\kedro\ipython\__init__.py#180\180]8;;\
#                              C:\Users\matia\OneDrive\Escritorio\ProyectoStarcraft\ProyectoMineria.
#                              To set a different path, run '%reload_kedro <project_root>'
#                     WARNING  C:\Users\matia\AppData\Local\Programs\Python\Python313\Lib\site-packag ]8;id=439031;file://C:\Users\matia\AppData\Local\Programs\Python\Python313\Lib\warnings.py\warnings.py]8;;\:]8;id=406612;file://C:\Users\matia\AppData\Local\Programs\Python\Python313\Lib\warnings.py#110\110]8;;\
#                              es\kedro\io\data_catalog.py:165: KedroDeprecationWarning:
#                              `DataCatalog` has been deprecated and will be replaced by
#                              `KedroDataCatalog`, in Kedro 1.0.0.Currently some `KedroDataCatalog`
#                              APIs have been retained for compatibility with `DataCatalog`,
#                              including the `datasets` property and the `get_datasets`,
#                              `_get_datasets`, `add`,` list`, `add_feed_dict`, and `shallow_copy`
#                              methods. These will be removed or replaced with updated alternatives
#                              in Kedro 1.0.0. For more details, refer to the documentation:
#                              https://docs.kedro.org/en/stable/data/index.html#kedrodatacatalog-expe
#                              rimental-feature
#                                warnings.warn(
# [04/13/25 01:44:47] WARNING  C:\Users\matia\AppData\Local\Programs\Python\Python313\Lib\site-packag ]8;id=633912;file://C:\Users\matia\AppData\Local\Programs\Python\Python313\Lib\warnings.py\warnings.py]8;;\:]8;id=232427;file://C:\Users\matia\AppData\Local\Programs\Python\Python313\Lib\warnings.py#110\110]8;;\
#                              es\kedro\io\data_catalog.py:165: KedroDeprecationWarning:
#                              `DataCatalog` has been deprecated and will be replaced by
#                              `KedroDataCatalog`, in Kedro 1.0.0.Currently some `KedroDataCatalog`
#                              APIs have been retained for compatibility with `DataCatalog`,
#                              including the `datasets` property and the `get_datasets`,
#                              `_get_datasets`, `add`,` list`, `add_feed_dict`, and `shallow_copy`
#                              methods. These will be removed or replaced with updated alternatives
#                              in Kedro 1.0.0. For more details, refer to the documentation:
#                              https://docs.kedro.org/en/stable/data/index.html#kedrodatacatalog-expe
#                              rimental-feature
#                                warnings.warn(
# [04/13/25 01:44:49] INFO     Kedro is sending anonymous usage data with the sole purpose of improving ]8;id=866747;file://C:\Users\matia\AppData\Local\Programs\Python\Python313\Lib\site-packages\kedro_telemetry\plugin.py\plugin.py]8;;\:]8;id=784650;file://C:\Users\matia\AppData\Local\Programs\Python\Python313\Lib\site-packages\kedro_telemetry\plugin.py#233\233]8;;\
#                              the product. No personal data or IP addresses are stored on our side. If
#                              you want to opt out, set the `KEDRO_DISABLE_TELEMETRY` or `DO_NOT_TRACK`
#                              environment variables, or create a `.telemetry` file in the current
#                              working directory with the contents `consent: false`. Read more at
#                              https://docs.kedro.org/en/stable/configuration/telemetry.html
# [04/13/25 01:44:50] INFO     Kedro project psicologia                                               ]8;id=473288;file://C:\Users\matia\AppData\Local\Programs\Python\Python313\Lib\site-packages\kedro\ipython\__init__.py\__init__.py]8;;\:]8;id=535213;file://C:\Users\matia\AppData\Local\Programs\Python\Python313\Lib\site-packages\kedro\ipython\__init__.py#146\146]8;;\
#                     INFO     Defined global variable 'context', 'session', 'catalog' and            ]8;id=920587;file://C:\Users\matia\AppData\Local\Programs\Python\Python313\Lib\site-packages\kedro\ipython\__init__.py\__init__.py]8;;\:]8;id=39253;file://C:\Users\matia\AppData\Local\Programs\Python\Python313\Lib\site-packages\kedro\ipython\__init__.py#147\147]8;;\
#                              'pipelines'

# %%
catalog

# %%
###%reload_kedro

# %% [markdown]
# ***Importamos las librerias para trabajar en esta fase.***

# %% [markdown]
# ***Cargaremos el dataset.***

# %%
df=catalog.load("starcraft_duoc")
df.head()
